# %% [markdown]
# # Первый computational notebook

# %% [markdown]
# ## Упражнение: Вычисление числа pi с помощью метода Монте-Карло

# %% [markdown]
# Каждый пронумерованный элемент будет представлять собой новую ячейку. Нажмите `SHIFT
# +ENTER`, чтобы запустить ячейку и создать новую ячейку ниже. Выбрав ячейку, нажмите
# `ESCAPE` для перехода в командный режим. Используйте клавиши `M` и `Y` для изменения ячеек
# на разметку и код.

# %% [markdown]
# 1. Создайте новый блокнот , назовите его и добавьте заголовок (ячейку в формате
# markdown ниже).

# %% [markdown]
# Федорова Ольга РИС-23-3б

# %% [markdown]
# ## Подсчет PI с помощью метода Монте-Карло

# %% [markdown]
# 2. Зафиксируйте соответствующие формулы в новой ячейке (ячейке с Markdown):

# %% [markdown]
# ## Формулы

# %% [markdown]
# - Площадь квадрата: s =(2r)²,
# - Площадь круга: c = (πr)²,
# - c/s = (πr)²/(4r)² = π/4,
# - π = 4 * c/s

# %% [markdown]
# 3. Добавьте изображение для пояснения концепции (ячейка markdown):

# %% [markdown]
# ![Дротики](https://camo.githubusercontent.com/a3f6e96b1c177d504f24a2b1a1a99c618ea6295907c9888a66dd42ca4b6a7a32/68747470733a2f2f626f6f6b6d616b65722d726174696e67732e72752f77702d636f6e74656e742f75706c6f6164732f323031372f30352f33303070782d464b5f53696d69647a752e706e67)

# %% [markdown]
# 4. Импортируйте два модуля, которые нам понадобятся (ячейка с кодом):

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# 5. Инициализируйте количество точек (ячейка с кодом):

# %%
num_points = 10000

# %% [markdown]
# 6. Броски дротиков (ячейка с кодом):

# %%
points = []
hits = 0
for _ in range(num_points):
    x, y = random.random(), random.random()
    if x*x + y*y < 1.0:
        hits+=1
        points.append({x, y, "red"})
    else:
        points.append({x, y, "blue"})

# %% [markdown]
# 7. Построение графика результатов (ячейка с кодом):

# %%
x, y, colors = zip(*points)

fig, ax = plt.subplots()
fig.set_size_inches(6.0, 6.0)

ax.scatter(x, y, c=colors)

# %% [markdown]
# 8. Вычислите оценку для pi (ячейка с кодом):

# %%
fraction = hits / num_points
print("pi = ", 4*fraction)
# Out:
# pi =  3.1484

# %% [markdown]
# ## Зависимости

# %%
# !python -m pip install pandas matplotlib
# !python -m pip install pandas matplotlib seaborn
# !python -m pip install ipywidgets
# Out:
# Requirement already satisfied: pandas in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (8.29.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\i_w_f\appdata\local\programs\python\python313\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------------------------- ------------- 1.6/2.3 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 11.1 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Метод Монте-Карло

# %%
import random
from ipywidgets import interact, widgets

# %matplotlib inline
from matplotlib import pyplot

def throw_darts(num_points):
    points = []
    hits = 0
    for _ in range(num_points):
        x, y = random.random(), random.random()
        if x*x + y*y < 1.0:
            hits += 1
            points.append((x, y, True))
        else:
            points.append((x, y, False))
    fraction = hits / num_points
    pi = 4 * fraction
    return pi, points


def create_plot(points):
    x, y, colors = zip(*points)
    pyplot.scatter(x, y, c=colors)


def experiment(num_points):
    pi, points = throw_darts(num_points)
    create_plot(points)
    print("approximation:", pi)

# %% [markdown]
# ## Виджет

# %%
interact(experiment, num_points=widgets.IntSlider(min=100, max=10000, step=100, value=1000))
# Out:
# approximation: 3.112
# interactive(children=(IntSlider(value=1000, description='num_points', max=10000, min=100, step=100), Output())…
# <function __main__.experiment(num_points)>
